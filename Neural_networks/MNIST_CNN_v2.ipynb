# %%
import numpy as np # to handle matrix and data operation
import pandas as pd # to read csv and handle dataframe

import torch # to load pytorch library
import torch.nn as nn # to load pytorch library
import torch.nn.functional as F # to load pytorch function
import torch.utils.data # to load data processor
from torch.autograd import Variable # pytorch data type
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('mnist_data/mnist_train.csv')
test = pd.read_csv('mnist_data/mnist_test.csv')
train.info()
test.info()

# split image and label
train_label = train.iloc[:, 0].values
train_img = train.iloc[:, 1:]
test_label = test.iloc[:, 0].values
test_img = test.iloc[:, 1:]
# check the dataset of one example
count=1
for a in range (10):
    imarray = train_img.iloc[a, :].values.reshape(28,28)
    plt.subplot(2,5,count)
    plt.subplots_adjust(hspace=0.1)
    count += 1
    plt.axis('off')
    plt.title("Label is " + str(train_label[a]))
    plt.imshow(imarray, cmap='Greys', interpolation='None')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59999 entries, 0 to 59998
# Columns: 785 entries, 5 to 0.617
# dtypes: int64(785)
# memory usage: 359.3 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Columns: 785 entries, 7 to 0.667
# dtypes: int64(785)
# memory usage: 59.9 MB

# %%
# reshape to be [samples][pixels][width][height]
train_img = train_img.values.reshape(-1,1,28,28)
test_img = test_img.values.reshape(-1,1,28,28)
train_img = train_img / 255.0
test_img = test_img / 255.0
# normalize inputs from 0-255 to 0-1
print(train_img.shape)
print(train_label.shape)
print(test_img.shape)
print(test_label.shape)

BATCH_SIZE = 1000

# create feature and targets tensor for training set.
torch_X_train = torch.from_numpy(train_img).float()
torch_y_train = torch.from_numpy(train_label)
# create feature and targets tensor for testing set.
torch_X_test = torch.from_numpy(test_img).float()
torch_y_test = torch.from_numpy(test_label)
# Pytorch train and test sets
train = torch.utils.data.TensorDataset(torch_X_train,torch_y_train)
test = torch.utils.data.TensorDataset(torch_X_test,torch_y_test)

# data loader
train_loader = torch.utils.data.DataLoader(train, batch_size = BATCH_SIZE, shuffle = False, num_workers=4)
test_loader = torch.utils.data.DataLoader(test, batch_size = BATCH_SIZE, shuffle = False, num_workers=4)
# Out:
# (59999, 1, 28, 28)
# (59999,)
# (9999, 1, 28, 28)
# (9999,)

# %%
# Defining the network (LeNet-5)
class LeNet5(nn.Module):
    #This defines the structure of the NN.
    def __init__(self):
        super(LeNet5, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5, stride=1, padding=2)
        self.act1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1, padding=0)
        self.act2 = nn.ReLU()
        self.maxpool2 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(in_features=400, out_features=120)
        self.act3 = nn.ReLU()
        self.fc2 = nn.Linear(in_features=120, out_features=84)
        self.act4 = nn.ReLU()
        self.fc3 = nn.Linear(in_features=84, out_features=10)

    def forward(self, x):
        #Convolutional Layer/Pooling Layer/Activation
        x = self.conv1(x)
        x = self.act1(x)
        x = self.maxpool1(x)
        #Convolutional Layer/Dropout/Pooling Layer/Activation
        x = self.conv2(x)
        x = self.act2(x)
        x = self.maxpool2(x)
        x = x.view(-1, 400)
        #Fully Connected Layer/Activation
        x = self.fc1(x)
        x = self.act3(x)
        #Fully Connected Layer/Activation
        x = self.fc2(x)
        x = self.act4(x)

        return self.fc3(x)

criterion = nn.CrossEntropyLoss()
if torch.cuda.is_available():
    criterion = criterion.cuda()

# %%
def train(model, epoch, optimizer):
    model.train()
    epoch_loss = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        if torch.cuda.is_available():
            data, target = data.cuda(), target.cuda()
        #Variables in Pytorch are differenciable.
        data, target = Variable(data), Variable(target)
        #This will zero out the gradients for this batch.
        optimizer.zero_grad()
        output = model(data)
        # Calculate the loss The negative log likelihood loss. It is useful to train a classification problem with C classes.
        loss = criterion(output, target)
        #dloss/dx for every Variable
        loss.backward()
        #to do a one-step update on our parameter.
        optimizer.step()
        epoch_loss += loss.item()
    #Print out the loss periodically.
    avg_loss = epoch_loss / len(train_loader)
    print("===> Epoch {} Complete: Training loss: {:.4f}".format(epoch, avg_loss))
    return avg_loss

# %%
def train_accuracy(model, epoch):
    model.eval()
    correct = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        if torch.cuda.is_available():
            data, target = data.cuda(), target.cuda()
        data, target = Variable(data), Variable(target)
        with torch.no_grad():
            output = model(data)
        _, predicted = torch.max(output.data, 1) # get the index of the max log-probability
        correct += (predicted == target).sum().item()
    avg_accuracy = correct / len(train_loader.dataset)
    print("===> Epoch {} Complete: Training accuracy: {:.4f}%".format(epoch, 100. * avg_accuracy))
    return avg_accuracy

# %%
def test(model, epoch):
    model.eval()
    correct = 0
    for batch_idx, (data, target) in enumerate(test_loader):
        if torch.cuda.is_available():
            data, target = data.cuda(), target.cuda()
            
        data, target = Variable(data), Variable(target)
        with torch.no_grad():
            output = model(data)
        _, predicted = torch.max(output.data, 1) # get the index of the max log-probability
        correct += (predicted == target).sum().item()
    avg_accuracy = correct / len(test_loader.dataset)
    print("===> Epoch {} Complete: Testing accuracy: {:.4f}%".format(epoch, 100. * avg_accuracy))
    return avg_accuracy

# %%
def checkpoint(model, epoch):
    model_out_path = "Training_epoch_{}.pth".format(epoch)
    torch.save(model.state_dict(), model_out_path)
    print("Checkpoint saved to {}".format(model_out_path))

# %%
model = LeNet5()

if torch.cuda.is_available():
    model.cuda() # set model to use GPU if available, defaults to CPU


optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.5)

# %% [markdown]
# **Task 1:**  A full loop that records the training loss and testing accuracy

# %%
train_losses = []
train_correct = []
test_correct = []

for epoch in range(1, 51, 1):

    # Trainining loss
    train_loss = train(model, epoch, optimizer)
    
    train_losses.append(train_loss)
    
    train_accuracy_data = train_accuracy(model, epoch)
    train_correct.append(train_accuracy_data)
    
    # Training accuracy
    # Testing accuracy
    test_accuracy = test(model, epoch)
    test_correct.append(test_accuracy)

    if epoch % 10 == 0:
        checkpoint(model, epoch)
        # Model checkpointing
        pass
# Out:
# ===> Epoch 1 Complete: Training loss: 2.3017
# ===> Epoch 1 Complete: Training accuracy: 10.1368%
# ===> Epoch 1 Complete: Testing accuracy: 10.1910%
# ===> Epoch 2 Complete: Training loss: 2.2951
# ===> Epoch 2 Complete: Training accuracy: 26.7854%
# ===> Epoch 2 Complete: Testing accuracy: 26.6327%
# ===> Epoch 3 Complete: Training loss: 2.2862
# ===> Epoch 3 Complete: Training accuracy: 28.3788%
# ===> Epoch 3 Complete: Testing accuracy: 28.9129%
# ===> Epoch 4 Complete: Training loss: 2.2692
# ===> Epoch 4 Complete: Training accuracy: 29.6122%
# ===> Epoch 4 Complete: Testing accuracy: 30.5831%
# ===> Epoch 5 Complete: Training loss: 2.2235
# ===> Epoch 5 Complete: Training accuracy: 35.0523%
# ===> Epoch 5 Complete: Testing accuracy: 35.6036%
# ===> Epoch 6 Complete: Training loss: 2.0198
# ===> Epoch 6 Complete: Training accuracy: 60.7243%
# ===> Epoch 6 Complete: Testing accuracy: 62.6563%
# ===> Epoch 7 Complete: Training loss: 1.2082
# ===> Epoch 7 Complete: Training accuracy: 75.7446%
# ===> Epoch 7 Complete: Testing accuracy: 76.3276%
# ===> Epoch 8 Complete: Training loss: 0.6792
# ===> Epoch 8 Complete: Training accuracy: 81.8214%
# ===> Epoch 8 Complete: Testing accuracy: 82.5083%
# ===> Epoch 9 Complete: Training loss: 0.5396
# ===> Epoch 9 Complete: Training accuracy: 85.1564%
# ===> Epoch 9 Complete: Testing accuracy: 85.6386%
# ===> Epoch 10 Complete: Training loss: 0.4654
# ===> Epoch 10 Complete: Training accuracy: 86.9431%
# ===> Epoch 10 Complete: Testing accuracy: 87.3687%
# Checkpoint saved to Training_epoch_10.pth
# ===> Epoch 11 Complete: Training loss: 0.4148
# ===> Epoch 11 Complete: Training accuracy: 88.1815%
# ===> Epoch 11 Complete: Testing accuracy: 88.7989%
# ===> Epoch 12 Complete: Training loss: 0.3773
# ===> Epoch 12 Complete: Training accuracy: 89.1982%
# ===> Epoch 12 Complete: Testing accuracy: 89.8790%
# ===> Epoch 13 Complete: Training loss: 0.3474
# ===> Epoch 13 Complete: Training accuracy: 90.0465%
# ===> Epoch 13 Complete: Testing accuracy: 90.6191%
# ===> Epoch 14 Complete: Training loss: 0.3225
# ===> Epoch 14 Complete: Training accuracy: 90.7482%
# ===> Epoch 14 Complete: Testing accuracy: 91.3191%
# ===> Epoch 15 Complete: Training loss: 0.3012
# ===> Epoch 15 Complete: Training accuracy: 91.3332%
# ===> Epoch 15 Complete: Testing accuracy: 91.9192%
# ===> Epoch 16 Complete: Training loss: 0.2824
# ===> Epoch 16 Complete: Training accuracy: 91.8482%
# ===> Epoch 16 Complete: Testing accuracy: 92.4692%
# ===> Epoch 17 Complete: Training loss: 0.2653
# ===> Epoch 17 Complete: Training accuracy: 92.3249%
# ===> Epoch 17 Complete: Testing accuracy: 92.8693%
# ===> Epoch 18 Complete: Training loss: 0.2497
# ===> Epoch 18 Complete: Training accuracy: 92.7899%
# ===> Epoch 18 Complete: Testing accuracy: 93.1893%
# ===> Epoch 19 Complete: Training loss: 0.2354
# ===> Epoch 19 Complete: Training accuracy: 93.2632%
# ===> Epoch 19 Complete: Testing accuracy: 93.7094%
# ===> Epoch 20 Complete: Training loss: 0.2225
# ===> Epoch 20 Complete: Training accuracy: 93.6199%
# ===> Epoch 20 Complete: Testing accuracy: 94.0294%
# Checkpoint saved to Training_epoch_20.pth
# ===> Epoch 21 Complete: Training loss: 0.2105
# ===> Epoch 21 Complete: Training accuracy: 93.9482%
# ===> Epoch 21 Complete: Testing accuracy: 94.2694%
# ===> Epoch 22 Complete: Training loss: 0.1996
# ===> Epoch 22 Complete: Training accuracy: 94.2366%
# ===> Epoch 22 Complete: Testing accuracy: 94.5295%
# ===> Epoch 23 Complete: Training loss: 0.1897
# ===> Epoch 23 Complete: Training accuracy: 94.4849%
# ===> Epoch 23 Complete: Testing accuracy: 94.7995%
# ===> Epoch 24 Complete: Training loss: 0.1807
# ===> Epoch 24 Complete: Training accuracy: 94.7449%
# ===> Epoch 24 Complete: Testing accuracy: 95.0495%
# ===> Epoch 25 Complete: Training loss: 0.1723
# ===> Epoch 25 Complete: Training accuracy: 94.9799%
# ===> Epoch 25 Complete: Testing accuracy: 95.2795%
# ===> Epoch 26 Complete: Training loss: 0.1647
# ===> Epoch 26 Complete: Training accuracy: 95.1916%
# ===> Epoch 26 Complete: Testing accuracy: 95.5096%
# ===> Epoch 27 Complete: Training loss: 0.1577
# ===> Epoch 27 Complete: Training accuracy: 95.3849%
# ===> Epoch 27 Complete: Testing accuracy: 95.6396%
# ===> Epoch 28 Complete: Training loss: 0.1512
# ===> Epoch 28 Complete: Training accuracy: 95.5833%
# ===> Epoch 28 Complete: Testing accuracy: 95.8096%
# ===> Epoch 29 Complete: Training loss: 0.1454
# ===> Epoch 29 Complete: Training accuracy: 95.7333%
# ===> Epoch 29 Complete: Testing accuracy: 95.8396%
# ===> Epoch 30 Complete: Training loss: 0.1399
# ===> Epoch 30 Complete: Training accuracy: 95.8633%
# ===> Epoch 30 Complete: Testing accuracy: 96.0096%
# Checkpoint saved to Training_epoch_30.pth
# ===> Epoch 31 Complete: Training loss: 0.1350
# ===> Epoch 31 Complete: Training accuracy: 95.9783%
# ===> Epoch 31 Complete: Testing accuracy: 96.1296%
# ===> Epoch 32 Complete: Training loss: 0.1304
# ===> Epoch 32 Complete: Training accuracy: 96.0933%
# ===> Epoch 32 Complete: Testing accuracy: 96.2896%
# ===> Epoch 33 Complete: Training loss: 0.1262
# ===> Epoch 33 Complete: Training accuracy: 96.2233%
# ===> Epoch 33 Complete: Testing accuracy: 96.3896%
# ===> Epoch 34 Complete: Training loss: 0.1223
# ===> Epoch 34 Complete: Training accuracy: 96.3516%
# ===> Epoch 34 Complete: Testing accuracy: 96.5397%
# ===> Epoch 35 Complete: Training loss: 0.1187
# ===> Epoch 35 Complete: Training accuracy: 96.4649%
# ===> Epoch 35 Complete: Testing accuracy: 96.6297%
# ===> Epoch 36 Complete: Training loss: 0.1153
# ===> Epoch 36 Complete: Training accuracy: 96.5699%
# ===> Epoch 36 Complete: Testing accuracy: 96.7697%
# ===> Epoch 37 Complete: Training loss: 0.1122
# ===> Epoch 37 Complete: Training accuracy: 96.6566%
# ===> Epoch 37 Complete: Testing accuracy: 96.8197%
# ===> Epoch 38 Complete: Training loss: 0.1093
# ===> Epoch 38 Complete: Training accuracy: 96.7233%
# ===> Epoch 38 Complete: Testing accuracy: 96.8697%
# ===> Epoch 39 Complete: Training loss: 0.1066
# ===> Epoch 39 Complete: Training accuracy: 96.7849%
# ===> Epoch 39 Complete: Testing accuracy: 96.9697%
# ===> Epoch 40 Complete: Training loss: 0.1040
# ===> Epoch 40 Complete: Training accuracy: 96.8516%
# ===> Epoch 40 Complete: Testing accuracy: 96.9497%
# Checkpoint saved to Training_epoch_40.pth
# ===> Epoch 41 Complete: Training loss: 0.1016
# ===> Epoch 41 Complete: Training accuracy: 96.9749%
# ===> Epoch 41 Complete: Testing accuracy: 97.0197%
# ===> Epoch 42 Complete: Training loss: 0.0993
# ===> Epoch 42 Complete: Training accuracy: 97.0550%
# ===> Epoch 42 Complete: Testing accuracy: 97.1597%
# ===> Epoch 43 Complete: Training loss: 0.0971
# ===> Epoch 43 Complete: Training accuracy: 97.1216%
# ===> Epoch 43 Complete: Testing accuracy: 97.1997%
# ===> Epoch 44 Complete: Training loss: 0.0951
# ===> Epoch 44 Complete: Training accuracy: 97.1816%
# ===> Epoch 44 Complete: Testing accuracy: 97.2397%
# ===> Epoch 45 Complete: Training loss: 0.0931
# ===> Epoch 45 Complete: Training accuracy: 97.2333%
# ===> Epoch 45 Complete: Testing accuracy: 97.2797%
# ===> Epoch 46 Complete: Training loss: 0.0913
# ===> Epoch 46 Complete: Training accuracy: 97.2600%
# ===> Epoch 46 Complete: Testing accuracy: 97.2997%
# ===> Epoch 47 Complete: Training loss: 0.0896
# ===> Epoch 47 Complete: Training accuracy: 97.3116%
# ===> Epoch 47 Complete: Testing accuracy: 97.3297%
# ===> Epoch 48 Complete: Training loss: 0.0879
# ===> Epoch 48 Complete: Training accuracy: 97.3516%
# ===> Epoch 48 Complete: Testing accuracy: 97.3597%
# ===> Epoch 49 Complete: Training loss: 0.0864
# ===> Epoch 49 Complete: Training accuracy: 97.3800%
# ===> Epoch 49 Complete: Testing accuracy: 97.3797%
# ===> Epoch 50 Complete: Training loss: 0.0849
# ===> Epoch 50 Complete: Training accuracy: 97.4100%
# ===> Epoch 50 Complete: Testing accuracy: 97.4397%
# Checkpoint saved to Training_epoch_50.pth

# %% [markdown]
# **Task 2.** Plot the training loss and testing accuracy VS epoches

# %%
import matplotlib.pyplot as plt


# Simulated data for demonstration (replace with real values from the training loop)

epochs = list(range(1, 51, 1))

# Plot training loss vs. epochs
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_losses, label="Training Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss vs. Epochs")
plt.legend()
plt.grid(True)
plt.show()

# Plot testing accuracy vs. epochs
plt.figure(figsize=(10, 5))
plt.plot(epochs, train_correct, label="Testing Accuracy", color="orange")
plt.xlabel("Epochs")
plt.ylabel("Accuracy (%)")
plt.title("Testing Accuracy vs. Epochs")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Task 3.** load pre-trained model and visualize the prediction on the testing samples.

# %%
model_name = 'Training_epoch_50.pth'
model.load_state_dict(torch.load(model_name, map_location=lambda storage, loc: storage)) # load the trained model
count=1
model.eval()
for a in range (10):
    imarray = test_img[a].reshape(1,1,28,28)
    data = torch.from_numpy(imarray).float()
    if torch.cuda.is_available():
        data = data.cuda()

    # Fill here:
    # Input the image to the loaded model
    # Get the predicted class labels using argmax or max on the model output

    plt.subplot(2,5,count)
    plt.subplots_adjust(hspace=0.2, wspace = 0.6)
    count += 1
    plt.axis('off')
    plt.title('GT: ' + str(test_label[a]) + ' Pred: ' + str(predicted.item()), fontsize=10)
    plt.imshow(imarray[0,0,:,:], cmap='Greys', interpolation='None')
# Out:
# /var/folders/sc/s6l29h_j7xx02f95pxl5ply40000gn/T/ipykernel_88711/1270013659.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_name, map_location=lambda storage, loc: storage)) # load the trained model
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[68], line 19
#      17 count += 1
#      18 plt.axis('off')
# ---> 19 plt.title('GT: ' + str(test_label[a]) + ' Pred: ' + str(predicted.item()), fontsize=10)
#      20 plt.imshow(imarray[0,0,:,:], cmap='Greys', interpolation='None')
#
# NameError: name 'predicted' is not defined

# %% [markdown]
# **Task 4.** Change the learning rate and retrain the model again, plot the new training loss and original training loss in one figure and explain your discovery.

# %%
model2 = LeNet5() # initialize a new model
if torch.cuda.is_available():
    model2.cuda() # Move the model to GPU if available
optimizer2 = ... # Fill a new optimizer

# %%
train_losses = []
train_correct = []
test_correct = []

for epoch in range(1, 51, 1):
    # Training loss
    # Training accuracy
    # Test accuracy
    ...

# %% [markdown]
# Plot accuracies and loss

# %%
# Simulated data for demonstration (replace with real values from the training loop)
training_accuracies = [50 + epoch / 2 for epoch in epochs]  # Example training accuracy increasing
testing_losses = [0.6 / epoch for epoch in epochs]  # Example testing loss decreasing over epochs

# Plot training and testing losses
plt.figure(figsize=(10, 5))
plt.plot(epochs, training_losses, label="Training Loss")
plt.plot(epochs, testing_losses, label="Testing Loss", linestyle="--")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Testing Loss vs. Epochs")
plt.legend()
plt.grid(True)
plt.show()

# Plot training and testing accuracies
plt.figure(figsize=(10, 5))
plt.plot(epochs, training_accuracies, label="Training Accuracy", color="blue")
plt.plot(epochs, testing_accuracies, label="Testing Accuracy", color="orange", linestyle="--")
plt.xlabel("Epochs")
plt.ylabel("Accuracy (%)")
plt.title("Training and Testing Accuracy vs. Epochs")
plt.legend()
plt.grid(True)
plt.show()
